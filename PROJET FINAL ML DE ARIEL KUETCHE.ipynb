# %% [markdown]
# # PROJET FINAL DE MACHINE LEARNING

# %% [markdown]
# # CONCEPTION D'UN CHATBOT POUR LA GESTION DES STAGIAIRES DANS UNE ENTREPRISE

# %% [markdown]
# ## IMPORTATION DES BIBLIOTHEQUES

# %%
import json
import numpy as np
import pandas as pd
import random
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# import tkinter as tk
# from tkinter import *

# %% [markdown]
# ## CHARGEMENT DES DONNEES

# %% [markdown]
# Les données sont chargées depuis le fichier JSON chatbot_data.json qui contient les intents avec les patterns et les tags.

# %%
# Charger les données
with open('intents.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
# Convertir le JSON en DataFrame
df = pd.DataFrame(data['intents'])

# Afficher le DataFrame dans le notebook
df
# Out:
#                         tag  \
# 0               salutations
# 1             annéeCréation
# 2   applicationsDéveloppées
# 3                 fondateur
# 4           domaineActivité
# 5             nombreEmployé
# 6             nomEntreprise
# 7                  auRevoir
# 8             remerciements
# 9                  invalide
# 10      structureEntreprise
# 11   localisationEntreprise
# 12            backend_tools
# 13           frontend_tools
# 14      communication_tools
# 15         horaireOuverture
# 16                   nokash
# 17               taxcollect
# 18                     pcpl
# 19             respoBackend
# 20            respoFrontend
# 21            respoSecurite
# 22              jourReunion
# 23      nbreStagiairePasser
# 24     participationPromote
# 25            jourNettoyage
# 26               ideBackend
# 27              ideFrontend
# 28            outilSecurite
# 29                 dataBase
# 30         toolsVersionning
# 31                documents
# 32                typeStage
#
#                                              patterns  \
# 0   [bonjour, salut, hey, coucou, hello, yo, Bonjo...
# 1   [Quand cette entreprise a-t-elle été fondée ?,...
# 2   [Quelles applications ont été développées par ...
# 3   [Qui a fondé cette entreprise ?, Qui est le cr...
# 4   [Quelle est l'activité principale de cette ent...
# 5   [Quel est le personnel actuel de l'entreprise ...
# 6   [Quel est le nom de l'entreprise ?, Comment s'...
# 7   [au revoir, à bientôt, à la prochaine, à plus ...
# 8   [merci, merci pour votre aide, merci beaucoup,...
# 9     [, yayayya, fzrgzrrgzr, hbvcjhdbvc, vgjvj, cul]
# 10  [Comment est structurée l'entreprise ?, Quelle...
# 11  [Où est située l'entreprise ?, Quelle est l'ad...
# 12  [Quels sont les principaux outils utilisés par...
# 13  [Quels sont les principaux outils utilisés par...
# 14  [Quels sont vos outils de communication au sei...
# 15  [Quand est-ce que vous êtes ouverts ?, Quels s...
# 16  [C'est quoi Nokash?, Qu'est-ce que Nokash?, Po...
# 17  [C'est quoi Taxcollect?, Qu'est-ce que Taxcoll...
# 18  [Qu'est-ce que PCPL?, C'est quoi PCPL?, Pourri...
# 19  [Qui supervise la cellule backend ?, À qui rev...
# 20  [Qui supervise la cellule frontend ?, À qui re...
# 21  [Qui supervise la sécurité au sein de l'entrep...
# 22  [Quels jours avez-vous des réunions en semaine...
# 23  [Combien de stagiaires avez-vous déjà eus jusq...
# 24  [L'entreprise a-t-elle déjà participé à Promot...
# 25  [Quels jours sont réservés pour le nettoyage d...
# 26  [Quels sont les IDE recommandés pour la cellul...
# 27  [Quels sont les IDE recommandés pour la cellul...
# 28  [Quels sont les outils de sécurité utilisés pa...
# 29  [Quels sont vos systèmes de gestion de bases d...
# 30  [Quels sont vos outils de versionning utilisés...
# 31  [Quels papiers sont nécessaires pour valider l...
# 32  [Quels types de stage proposez-vous ici ?, Que...
#
#                                             responses
# 0   [Salut !, Hey ! Comment puis-je vous aider ?, ...
# 1   [Elle a été créée en 2017., Cette entreprise a...
# 2   [Les produits logiciels déjà créés par l'entre...
# 3   [Ngeufack Thierry est le créateur de l'entrepr...
# 4   [Le domaine d'activité de l'entreprise est le ...
# 5   [L'entreprise emploie actuellement 8 personnes...
# 6   [L'entreprise a pour nom Boost Compagny Inc., ...
# 7   [Au revoir ! Si vous avez d'autres questions, ...
# 8   [De rien ! Si vous avez besoin d'aide à l'aven...
# 9   [Je suis désolé, je n'ai pas bien compris. Pou...
# 10  [Les produits logiciels déjà créés par l'entre...
# 11  [La localisation de l'entreprise est Cameroun,...
# 12  [Les outils utilisés dans la cellule backend s...
# 13  [Les outils utilisés dans la cellule frontend ...
# 14  [Les outils de communication utilisés dans l'e...
# 15  [L'entreprise est ouverte du lundi au vendredi...
# 16  [Nokash est une plateforme d'intégration de pa...
# 17  [Taxcollect est une application web et mobile ...
# 18  [PCPL est une application mobile nommée Pas Ch...
# 19  [Monsieur Lionel FEUDJIO est le responsable de...
# 20  [Monsieur Brice EYEBE est le responsable de la...
# 21  [Monsieur Alain François est le responsable de...
# 22  [Nos réunions ont lieu le mercredi et le vendr...
# 23  [Depuis sa création, 16 stagiaires ont été acc...
# 24  [Oui, notre entreprise a participé à Promote e...
# 25  [Les jours de nettoyage des bureaux sont le ma...
# 26  [Les IDE utilisés dans la cellule backend sont...
# 27  [L'IDE utilisé dans la cellule frontend est Vi...
# 28  [Les outils utilisés par la cellule de sécurit...
# 29  [Les systèmes de gestion de base de données qu...
# 30  [Les outils de versionning que nous utilisons ...
# 31  [Il faudra une photocopie de la CNI, un certif...
# 32  [Un stage académique, un stage professionnel e...

# %% [markdown]
# ## PREPARATION DES DONNEES

# %% [markdown]
# Les patterns (questions) sont extraits dans X et les tags (intentions) dans y.

# %%
# Extraire les intents, questions et réponses
intents = data['intents']
patterns = []
tags = []
responses = {}

for intent in intents:
    for pattern in intent['patterns']:
        patterns.append(pattern)
        tags.append(intent['tag'])
    responses[intent['tag']] = intent['responses']

# Transformation des intentions en nombres
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(tags)

# %%
patterns
# Out:
# ['bonjour',
#  'salut',
#  'hey',
#  'coucou',
#  'hello',
#  'yo',
#  'Bonjour',
#  'Bonne journée',
#  'Bon matin',
#  'Bon après-midi',
#  'Bonsoir',
#  'Bonne journée à vous',
#  'Enchanté',
#  'Comment allez-vous ?',
#  'Coucou',
#  'Yo',
#  'Hey',
#  'Allo',
#  'Ça va ?',
#  'Salut les amis',
#  'Hé, salut !',
#  'Quoi de neuf ?',
#  'Tiens',
#  'Salutations',
#  'Salut tout le monde',
#  'Bonjour à tous',
#  'Bonjour tout le monde',
#  'Salut à tous',
#  'Hello tout le monde',
#  'Bon matin à tous',
#  'Bonsoir à tous',
#  'Coucou tout le monde',
#  'Hey tout le monde',
#  'Bonjour les amis',
#  'Salut les gens',
#  'Hello les amis',
#  'Hey les amis',
#  'Salut la compagnie',
#  'Bonjour la compagnie',
#  'Coucou la compagnie',
#  'Hello la compagnie',
#  'Hey la compagnie',
#  'Salut, ça va ?',
#  'Bonjour, comment ça va ?',
#  'Salut, quoi de neuf ?',
#  'Hello, comment allez-vous ?',
#  'Hey, ça va ?',
#  'Salut, comment ça roule ?',
#  'Bonjour, ça fait plaisir de vous voir',
#  'Hello, ça fait plaisir de vous voir',
#  'Salut, comment vous sentez-vous ?',
#  'Bonjour, comment se passe votre journée ?',
#  'Coucou, comment ça va ?',
#  'Hello, quoi de neuf ?',
#  'Salut, quoi de neuf chez vous ?',
#  'Bonjour, quoi de nouveau ?',
#  'Salut, tout va bien ?',
#  "Bonjour, comment ça va aujourd'hui ?",
#  'Hey, quoi de neuf ?',
#  'Coucou, ça va ?',
#  'Hello, comment allez-vous ?',
#  'Salut, tout se passe bien ?',
#  'Bonjour, comment ça va ?',
#  "Hey, comment ça va aujourd'hui ?",
#  'Salut, quoi de beau ?',
#  'Bonjour, quoi de beau ?',
#  'Hello, tout va bien ?',
#  'Salut, comment ça va ?',
#  'Bonjour, tout va bien ?',
#  'Coucou, quoi de neuf ?',
#  'Hey, tout se passe bien ?',
#  'Bonjour, comment ça roule ?',
#  'Salut, comment se passe votre journée ?',
#  'Hello, comment se passe votre journée ?',
#  'Coucou, tout va bien ?',
#  'Salut, ça roule ?',
#  'Bonjour, ça roule ?',
#  'Hey, ça roule ?',
#  'Hello, quoi de neuf ?',
#  "Salut, comment allez-vous aujourd'hui ?",
#  "Bonjour, comment allez-vous aujourd'hui ?",
#  'Salut, comment ça va chez vous ?',
#  'Hello, comment ça va chez vous ?',
#  'Hey, comment se passe votre journée ?',
#  "Salut, quoi de neuf aujourd'hui ?",
#  "Bonjour, quoi de neuf aujourd'hui ?",
#  'Coucou, comment allez-vous ?',
#  'Salut, comment ça se passe ?',
#  'Bonjour, comment ça se passe ?',
#  'Hey, comment ça se passe ?',
#  "Hello, comment ça va aujourd'hui ?",
#  'Salut, comment allez-vous ?',
#  'Bonjour, tout va bien chez vous ?',
#  'Coucou, tout va bien chez vous ?',
#  'Hello, tout va bien chez vous ?',
#  'Quand cette entreprise a-t-elle été fondée ?',
#  'Depuis quelle année cette entreprise existe-t-elle ?',
#  'Quelle année marque la création de cette entreprise ?',
#  'Quand est-ce que cette entreprise a vu le jour ?',
#  'Depuis quand cette entreprise fonctionne-t-elle ?',
#  'Quand cette entreprise a-t-elle été constituée ?',
#  'À quelle époque cette entreprise a-t-elle été fondée ?',
#  'Depuis combien de temps cette entreprise existe-t-elle ?',
#  'Quelle est la date de création de cette entreprise ?',
#  'En quelle année cette entreprise a-t-elle été lancée ?',
#  "Quel est l'année de fondation de cette entreprise ?",
#  'Depuis quand cette entreprise a-t-elle commencé ses activités ?',
#  'Quand cette entreprise a-t-elle été mise en place ?',
#  'À partir de quelle année cette entreprise est-elle active ?',
#  "Quelle est l'année de lancement de cette entreprise ?",
#  'À quel moment cette entreprise a-t-elle vu le jour ?',
#  'Depuis quand cette entreprise est-elle en service ?',
#  'Quand cette entreprise a-t-elle été initiée ?',
#  'À quelle date cette entreprise a-t-elle débuté ?',
#  "Depuis combien d'années cette entreprise est-elle en activité ?",
#  'Depuis quelle période cette entreprise existe-t-elle ?',
#  "Quelle est l'année de départ de cette entreprise ?",
#  'Quand cette entreprise a-t-elle commencé ?',
#  'À partir de quand cette entreprise est-elle opérationnelle ?',
#  'Depuis combien de temps cette entreprise est-elle active ?',
#  'En quelle année cette entreprise a-t-elle commencé ses activités ?',
#  'Quand cette entreprise a-t-elle été créée officiellement ?',
#  'Depuis quelle année cette entreprise est-elle en service ?',
#  'Quelle est la date de démarrage de cette entreprise ?',
#  'Quand cette entreprise a-t-elle été fondée officiellement ?',
#  "Quelle est l'année de mise en place de cette entreprise ?",
#  'À quel moment cette entreprise a-t-elle démarré ?',
#  'Depuis quand cette entreprise est-elle active ?',
#  'Quand cette entreprise a-t-elle pris son départ ?',
#  'À quelle période cette entreprise a-t-elle été créée ?',
#  'Depuis combien de temps cette entreprise existe-t-elle ?',
#  'En quelle année cette entreprise a-t-elle débuté ses activités ?',
#  'Quand cette entreprise a-t-elle été établie officiellement ?',
#  'Depuis quelle époque cette entreprise est-elle opérationnelle ?',
#  "Quelle est l'année de lancement officiel de cette entreprise ?",
#  'Quand cette entreprise a-t-elle été mise sur pied ?',
#  'À partir de quelle année cette entreprise a-t-elle été fondée ?',
#  'Quelle année marque le début de cette entreprise ?',
#  'Depuis quand cette entreprise est-elle en fonction ?',
#  'Quand cette entreprise a-t-elle vu officiellement le jour ?',
#  'À quelle date cette entreprise a-t-elle été initiée ?',
#  'Depuis quelle année cette entreprise est-elle en activité ?',
#  'Quelle est la date officielle de création de cette entreprise ?',
#  'Quand cette entreprise a-t-elle été mise en place officiellement ?',
#  'Quelles applications ont été développées par cette entreprise ?',
#  'Pouvez-vous me donner la liste des applications déjà développées par cette entreprise ?',
#  'Quels sont les logiciels que cette entreprise a déjà créés ?',
#  "Avez-vous des exemples d'applications déjà mises au point par cette entreprise ?",
#  'Quelles sont les applications développées par cette société ?',
#  "Pourriez-vous me citer quelques-unes des applications qu'elle a développées ?",
#  "Y a-t-il des exemples d'applications déjà réalisées par cette entreprise ?",
#  "Quels sont les produits logiciels conçus par cette entreprise jusqu'à présent ?",
#  'Quelles sont les applications existantes produites par cette société ?',
#  'Pourriez-vous me donner des informations sur les applications déjà développées par cette entreprise ?',
#  'Qui a fondé cette entreprise ?',
#  'Qui est le créateur de cette entreprise ?',
#  'Qui a lancé cette entreprise ?',
#  'Quelle personne a établi cette entreprise ?',
#  "Qui est à l'origine de cette entreprise ?",
#  'Quel individu a démarré cette entreprise ?',
#  'Qui est le fondateur de cette société ?',
#  "Qui est l'initiateur de cette entreprise ?",
#  'Quel est le nom du fondateur de cette entreprise ?',
#  'Qui a établi cette société ?',
#  'Qui a mis en place cette entreprise ?',
#  'Quel est le nom de la personne qui a créé cette entreprise ?',
#  'Quel est le nom de la personne qui a fondé cette société ?',
#  'Qui est la personne derrière la création de cette entreprise ?',
#  'Qui a été le pionnier de cette entreprise ?',
#  'Quel est le nom du créateur de cette entreprise ?',
#  'Qui est responsable de la fondation de cette entreprise ?',
#  'Quel est le fondateur de cette entreprise ?',
#  'Quelle personne a commencé cette entreprise ?',
#  "Qui est à l'initiative de cette entreprise ?",
#  'Qui est le cerveau derrière cette entreprise ?',
#  'Qui a initié cette entreprise ?',
#  'Qui a mis sur pied cette entreprise ?',
#  'Qui est le fondateur de cette entreprise ?',
#  'Qui a commencé cette société ?',
#  'Quel est le nom du créateur de cette société ?',
#  "Qui est l'instigateur de cette entreprise ?",
#  'Qui a fondé cette société ?',
#  'Qui est le promoteur de cette entreprise ?',
#  'Qui a établi cette entreprise ?',
#  "Quel individu est à l'origine de cette entreprise ?",
#  'Qui a été le fondateur de cette entreprise ?',
#  "Qui a été à l'initiative de cette entreprise ?",
#  'Quel est le nom du pionnier de cette entreprise ?',
#  'Qui a conçu cette entreprise ?',
#  'Qui a initié la création de cette entreprise ?',
#  "Quel est le nom de l'initiateur de cette entreprise ?",
#  'Qui a réalisé la fondation de cette entreprise ?',
#  "Qui est l'âme derrière cette entreprise ?",
#  "Qui a été à l'origine de cette entreprise ?",
#  'Qui a été le premier à créer cette entreprise ?',
#  'Quel est le nom de celui qui a fondé cette entreprise ?',
#  'Qui a orchestré la création de cette entreprise ?',
#  'Qui a donné naissance à cette entreprise ?',
#  'Qui est la personne fondatrice de cette entreprise ?',
#  'Qui a été le moteur derrière cette entreprise ?',
#  "Quel est le nom de l'instigateur de cette entreprise ?",
#  'Qui a été le créateur de cette entreprise ?',
#  'Qui est le principal fondateur de cette entreprise ?',
#  'Qui a entrepris de créer cette entreprise ?',
#  "Quelle est l'activité principale de cette entreprise ?",
#  'De quoi cette entreprise se spécialise-t-elle ?',
#  'Dans quel domaine opère cette entreprise ?',
#  "Quels sont les domaines d'expertise de cette entreprise ?",
#  'Quelles sont les principales fonctions de cette entreprise ?',
#  'Dans quels secteurs cette entreprise est-elle active ?',
#  'Quels produits ou services cette entreprise propose-t-elle ?',
#  'Dans quel domaine cette entreprise exerce-t-elle ses activités ?',
#  "Quel est le champ d'action de cette entreprise ?",
#  'Dans quelle industrie évolue cette entreprise ?',
#  "Quels sont les principaux secteurs d'activité de cette entreprise ?",
#  'Dans quel domaine cette entreprise est-elle spécialisée ?',
#  'Quels sont les services offerts par cette entreprise ?',
#  'Quels sont les produits fournis par cette entreprise ?',
#  'Dans quels domaines cette entreprise intervient-elle ?',
#  'Quel est le cœur de métier de cette entreprise ?',
#  'Quel est le secteur principal de cette entreprise ?',
#  'Dans quelle branche cette entreprise opère-t-elle ?',
#  'Quelles sont les spécialités de cette entreprise ?',
#  "Quels sont les champs d'expertise de cette entreprise ?",
#  'Quels types de services cette entreprise propose-t-elle ?',
#  'Quels sont les principaux produits de cette entreprise ?',
#  "Quels sont les domaines d'activité de cette entreprise ?",
#  "Dans quel secteur d'activité cette entreprise est-elle active ?",
#  'Quels sont les principaux services de cette entreprise ?',
#  'Dans quels domaines cette entreprise se spécialise-t-elle ?',
#  'Quel type de services cette entreprise offre-t-elle ?',
#  'Quels types de produits cette entreprise offre-t-elle ?',
#  'Quels sont les domaines de compétence de cette entreprise ?',
#  "Quel est le secteur d'activité de cette entreprise ?",
#  'Quels sont les principaux services fournis par cette entreprise ?',
#  'Quels sont les principaux produits offerts par cette entreprise ?',
#  "Quels sont les principaux champs d'action de cette entreprise ?",
#  'Dans quel secteur cette entreprise est-elle spécialisée ?',
#  'Quels sont les principaux services proposés par cette entreprise ?',
#  'Quels sont les produits principaux de cette entreprise ?',
#  "Quels sont les principaux champs d'expertise de cette entreprise ?",
#  "Quels sont les principaux domaines d'intervention de cette entreprise ?",
#  "Quel est le domaine d'intervention de cette entreprise ?",
#  'Dans quels secteurs cette entreprise opère-t-elle ?',
#  "Quels sont les principaux domaines d'activité de cette entreprise ?",
#  'Dans quel domaine cette entreprise évolue-t-elle ?',
#  "Quels sont les secteurs d'intervention de cette entreprise ?",
#  'Quels sont les principaux domaines de cette entreprise ?',
#  "Quel est le secteur d'intervention de cette entreprise ?",
#  'Quels sont les services principaux de cette entreprise ?',
#  'Quels sont les domaines principaux de cette entreprise ?',
#  "Quel est le champ principal d'action de cette entreprise ?",
#  'Dans quelle branche cette entreprise évolue-t-elle ?',
#  "Quels sont les secteurs d'activité de cette entreprise ?",
#  "Quel est le personnel actuel de l'entreprise ?",
#  'Combien de collaborateurs avez-vous actuellement ?',
#  'Quel est le nombre actuel de travailleurs dans votre entreprise ?',
#  "Combien d'individus sont employés par votre société en ce moment ?",
#  'Quelle est la taille de votre équipe actuelle ?',
#  'Combien de personnes composent votre équipe actuellement ?',
#  "Combien de membres du personnel avez-vous à l'heure actuelle ?",
#  'Quel est le nombre total de travailleurs dans votre entreprise ?',
#  'Combien de personnel est actuellement en activité chez vous ?',
#  'Pouvez-vous indiquer combien de personnes travaillent dans votre société ?',
#  'Actuellement, quel est le nombre de vos employés ?',
#  'Combien de ressources humaines avez-vous actuellement ?',
#  'Quelle est la capacité actuelle de votre équipe ?',
#  'Combien de salariés comptez-vous en ce moment ?',
#  "Quel est l'effectif de votre entreprise en ce moment ?",
#  'Combien de personnes sont actuellement dans votre équipe ?',
#  'Combien de gens travaillent pour vous actuellement ?',
#  'Quelle est la force de travail actuelle de votre société ?',
#  'Combien de personnes sont employées chez vous actuellement ?',
#  "Combien d'employés avez-vous à ce jour ?",
#  'Quel est le total actuel des employés dans votre entreprise ?',
#  'Combien de travailleurs avez-vous actuellement ?',
#  'Quel est le chiffre actuel des employés chez vous ?',
#  'Actuellement, quel est le nombre de salariés dans votre société ?',
#  'Combien de personnes sont à votre emploi actuellement ?',
#  "Quel est le nombre d'employés actifs chez vous en ce moment ?",
#  'Combien de membres du personnel avez-vous en ce moment ?',
#  "Combien d'individus travaillent dans votre société à l'heure actuelle ?",
#  'Pouvez-vous me dire combien de salariés vous avez actuellement ?',
#  'Combien de personnes constituent votre personnel actuel ?',
#  "Quel est le nombre d'employés que vous avez actuellement ?",
#  'Actuellement, combien de collaborateurs avez-vous ?',
#  'Combien de gens sont employés par votre société en ce moment ?',
#  'Quelle est la taille actuelle de votre personnel ?',
#  'Combien de personnes sont actuellement employées dans votre société ?',
#  'Combien de salariés avez-vous dans votre équipe actuelle ?',
#  "Quel est le nombre d'individus travaillant dans votre entreprise actuellement ?",
#  'Combien de collaborateurs compte votre société actuellement ?',
#  'Combien de personnes font partie de votre équipe en ce moment ?',
#  "Quel est l'effectif de votre équipe actuelle ?",
#  "Combien de membres d'équipe avez-vous actuellement ?",
#  'Actuellement, combien de membres du personnel avez-vous ?',
#  'Pouvez-vous me donner le nombre actuel de vos employés ?',
#  "Quel est le nombre d'employés dans votre société actuellement ?",
#  'Combien de personnes travaillent actuellement chez vous ?',
#  'Combien de salariés sont employés par votre société en ce moment ?',
#  'Quel est le total des effectifs de votre entreprise actuellement ?',
#  "Combien de personnes sont dans votre équipe à l'heure actuelle ?",
#  'Combien de membres du personnel comptabilisez-vous en ce moment ?',
#  "Pouvez-vous m'indiquer le nombre actuel d'employés dans votre entreprise ?",
#  "Quel est le nom de l'entreprise ?",
#  "Comment s'appelle cette entreprise ?",
#  "Le nom de l'entreprise est lequel ?",
#  'Pouvez-vous me dire le nom de votre entreprise ?',
#  'Quel est le nom officiel de votre entreprise ?',
#  'Quel est le nom sous lequel votre entreprise est enregistrée ?',
#  'Pourriez-vous me fournir le nom de votre entreprise ?',
#  'Quel nom est associé à votre entreprise ?',
#  "Avez-vous un nom d'entreprise spécifique ?",
#  "Je souhaiterais connaître le nom de votre entreprise, s'il vous plaît.",
#  'Quel est le nom de votre société ?',
#  'Comment se nomme votre entreprise ?',
#  'Sous quel nom votre entreprise est-elle connue ?',
#  'Quel est le nom légal de votre entreprise ?',
#  'Quel est le nom complet de votre entreprise ?',
#  'Quel est le titre de votre entreprise ?',
#  'Pourriez-vous me dire le nom exact de votre entreprise ?',
#  'Quel est le nom de votre organisation ?',
#  'Quel est le nom commercial de votre entreprise ?',
#  'Comment identifiez-vous votre entreprise ?',
#  'Sous quel nom opère votre entreprise ?',
#  'Pouvez-vous me dire sous quel nom votre entreprise est enregistrée ?',
#  'Quel nom porte votre entreprise ?',
#  'Comment votre entreprise est-elle appelée ?',
#  'Quel est le nom de la société que vous représentez ?',
#  'Quel est le nom officiel enregistré de votre entreprise ?',
#  "Quel est le nom d'enregistrement de votre entreprise ?",
#  'Quel est le nom de votre compagnie ?',
#  'Sous quel nom votre entreprise fait-elle affaire ?',
#  'Pouvez-vous me communiquer le nom de votre entreprise ?',
#  'Quel est le nom sous lequel vous opérez ?',
#  "Quel est le nom d'usage de votre entreprise ?",
#  'Quel est le nom sous lequel vous faites des affaires ?',
#  "Quel est le nom de votre entreprise, s'il vous plaît ?",
#  'Comment appelle-t-on votre entreprise ?',
#  'Quel est le nom officiel sous lequel vous exercez ?',
#  "Comment s'appelle votre société ?",
#  'Quel est le nom juridique de votre entreprise ?',
#  'Sous quelle dénomination votre entreprise est-elle connue ?',
#  'Quel est le nom de votre structure ?',
#  'Comment votre entreprise est-elle identifiée ?',
#  "Pouvez-vous m'indiquer le nom de votre entreprise ?",
#  'Quel est le nom sous lequel votre société est enregistrée ?',
#  'Quel nom donnez-vous à votre entreprise ?',
#  'Quel est le nom officiel que porte votre entreprise ?',
#  'Quel est le nom formel de votre entreprise ?',
#  'Quel est le nom sous lequel votre entreprise est légalement enregistrée ?',
#  'Pouvez-vous me dire quel nom porte votre entreprise ?',
#  'au revoir',
#  'à bientôt',
#  'à la prochaine',
#  'à plus tard',
#  'adieu',
#  "à tout à l'heure",
#  'à tout de suite',
#  'à demain',
#  'à la revoyure',
#  'à la semaine prochaine',
#  'à la prochaine fois',
#  'à la prochaine occasion',
#  'à très bientôt',
#  'à la revoyure',
#  'à tout de suite',
#  'à plus',
#  "à tout à l'heure",
#  'à tout de suite',
#  'à plus tard',
#  'à la prochaine',
#  'à bientôt',
#  'à la revoyure',
#  'à demain',
#  'à une autre fois',
#  'à une prochaine fois',
#  'à la semaine prochaine',
#  'à très vite',
#  'à la prochaine occasion',
#  'au plaisir',
#  'au revoir et à bientôt',
#  'au revoir et à la prochaine',
#  'au revoir et à très bientôt',
#  'au plaisir de vous revoir',
#  'au plaisir de se revoir',
#  'à une prochaine',
#  'je vous dis au revoir',
#  'je vous dis à bientôt',
#  'je vous dis à la prochaine',
#  'je vous dis à très bientôt',
#  "je vous dis à tout à l'heure",
#  'je vous dis à tout de suite',
#  'je vous dis à plus tard',
#  'je vous dis adieu',
#  'je vous dis à demain',
#  'je vous dis à la semaine prochaine',
#  'je vous dis à la revoyure',
#  'je vous dis à la prochaine fois',
#  'je vous dis à la prochaine occasion',
#  'je vous dis à très vite',
#  'je vous dis au plaisir',
#  'je vous dis au revoir et à bientôt',
#  'je vous dis au revoir et à la prochaine',
#  'je vous dis au revoir et à très bientôt',
#  'je vous dis au plaisir de vous revoir',
#  'je vous dis au plaisir de se revoir',
#  'je vous dis à une prochaine',
#  'je vous dis à une prochaine fois',
#  'je vous dis à la semaine prochaine',
#  'je vous dis à une autre fois',
#  'je vous dis à la prochaine occasion',
#  'je vous dis au revoir et à très vite',
#  'je vous dis à plus',
#  'je vous dis à la revoyure',
#  'merci',
#  'merci pour votre aide',
#  'merci beaucoup',
#  'merci bien',
#  'un grand merci',
#  'merci infiniment',
#  'merci pour ça',
#  'merci pour tout',
#  'merci pour votre soutien',
#  'merci pour votre collaboration',
#  'je vous remercie',
#  'je vous suis reconnaissant',
#  'je vous suis reconnaissant pour ça',
#  'je vous suis reconnaissant pour votre aide',
#  'je vous suis reconnaissant pour tout',
#  'je vous remercie beaucoup',
#  'un immense merci',
#  'je vous suis très reconnaissant',
#  'merci pour votre précieuse aide',
#  'merci pour votre assistance',
#  'merci pour votre intervention',
#  'merci pour vos efforts',
#  'merci pour votre temps',
#  'merci pour votre dévouement',
#  'merci pour votre patience',
#  'merci pour votre compréhension',
#  'merci pour votre attention',
#  'merci pour votre écoute',
#  'merci pour votre implication',
#  'merci pour votre support',
#  'merci pour votre contribution',
#  'merci pour vos précieux conseils',
#  'merci pour votre bienveillance',
#  'merci pour votre professionnalisme',
#  'merci pour votre générosité',
#  'merci pour votre gentillesse',
#  'merci pour votre disponibilité',
#  'merci pour votre réponse rapide',
#  'merci pour votre réactivité',
#  'merci pour votre efficacité',
#  'merci pour votre excellent travail',
#  'merci pour votre collaboration précieuse',
#  'merci pour tout ce que vous avez fait',
#  'merci pour tout ce que vous faites',
#  'merci pour votre soutien continu',
#  'merci pour votre engagement',
#  'merci pour votre implication constante',
#  'merci pour votre implication quotidienne',
#  'merci pour votre travail acharné',
#  'merci pour votre dévouement inlassable',
#  'merci pour votre passion',
#  'merci pour votre contribution essentielle',
#  '',
#  'yayayya',
#  'fzrgzrrgzr',
#  'hbvcjhdbvc',
#  'vgjvj',
#  'cul',
#  "Comment est structurée l'entreprise ?",
#  'Quelle est la structure de votre entreprise ?',
#  "Pouvez-vous m'expliquer la structure organisationnelle de votre entreprise ?",
#  'Comment votre entreprise est-elle organisée ?',
#  "Quelle est l'organisation interne de votre entreprise ?",
#  'Comment se présente la structure de votre entreprise ?',
#  'Pouvez-vous décrire la structure de votre entreprise ?',
#  'Comment est organisée votre entreprise ?',
#  "Comment se compose l'organisation de votre entreprise ?",
#  'Quelle est la disposition organisationnelle de votre entreprise ?',
#  'Pouvez-vous me parler de la structure de votre entreprise ?',
#  'Comment est définie la structure de votre entreprise ?',
#  'Comment est établie la structure organisationnelle de votre entreprise ?',
#  'Quelle est la configuration de votre entreprise ?',
#  'Quelle est la structure hiérarchique de votre entreprise ?',
#  'Pouvez-vous expliquer la structure de votre entreprise ?',
#  'Comment est répartie la structure de votre entreprise ?',
#  'Quelle est la répartition structurelle de votre entreprise ?',
#  "Comment se répartit l'organisation de votre entreprise ?",
#  "Quelle est l'organisation hiérarchique de votre entreprise ?",
#  'Comment votre entreprise est-elle structurée ?',
#  'Pouvez-vous décrire la disposition organisationnelle de votre entreprise ?',
#  'Comment est constituée la structure de votre entreprise ?',
#  'Quelle est la structure interne de votre entreprise ?',
#  'Comment se structure votre entreprise ?',
#  'Pouvez-vous détailler la structure de votre entreprise ?',
#  'Comment votre entreprise est-elle hiérarchisée ?',
#  'Quelle est la configuration organisationnelle de votre entreprise ?',
#  'Comment se divise la structure de votre entreprise ?',
#  'Pouvez-vous expliquer la configuration de votre entreprise ?',
#  "Comment est répartie l'organisation de votre entreprise ?",
#  'Quelle est la disposition hiérarchique de votre entreprise ?',
#  "Comment se structure l'organisation interne de votre entreprise ?",
#  'Quelle est la répartition hiérarchique de votre entreprise ?',
#  'Comment se compose la hiérarchie de votre entreprise ?',
#  "Pouvez-vous décrire l'organisation de votre entreprise ?",
#  "Comment se présente l'organisation de votre entreprise ?",
#  'Quelle est la hiérarchie de votre entreprise ?',
#  'Comment se définit la structure de votre entreprise ?',
#  "Quelle est l'architecture organisationnelle de votre entreprise ?",
#  'Pouvez-vous décrire la répartition structurelle de votre entreprise ?',
#  "Comment se structure l'organisation hiérarchique de votre entreprise ?",
#  'Quelle est la configuration interne de votre entreprise ?',
#  "Pouvez-vous détailler l'organisation de votre entreprise ?",
#  'Comment se répartit la hiérarchie de votre entreprise ?',
#  'Quelle est la composition structurelle de votre entreprise ?',
#  "Comment est définie l'organisation de votre entreprise ?",
#  "Quelle est l'organisation structurelle de votre entreprise ?",
#  "Comment se compose l'organisation hiérarchique de votre entreprise ?",
#  'Pouvez-vous détailler la hiérarchie de votre entreprise ?',
#  "Où est située l'entreprise ?",
#  "Quelle est l'adresse de l'entreprise ?",
#  'Où se trouve votre entreprise ?',
#  'Pouvez-vous me dire où est située votre entreprise ?',
#  "Quel est l'emplacement de votre entreprise ?",
#  'Où est localisée votre entreprise ?',
#  'Dans quelle ville se trouve votre entreprise ?',
#  'Où est votre entreprise ?',
#  'Où est-ce que votre entreprise est située ?',
#  'Quel est le lieu de votre entreprise ?',
#  'Quelle est la localisation de votre entreprise ?',
#  'Votre entreprise est située où ?',
#  'Où se situe votre siège social ?',
#  'Dans quelle région se trouve votre entreprise ?',
#  'Où se trouve votre siège social ?',
#  'Où votre entreprise a-t-elle son siège ?',
#  "Pouvez-vous me donner l'adresse de votre entreprise ?",
#  'Où est implantée votre entreprise ?',
#  'Où est installée votre entreprise ?',
#  "Quel est le lieu d'implantation de votre entreprise ?",
#  'Où peut-on trouver votre entreprise ?',
#  'Votre entreprise se situe où ?',
#  "Quelle est l'adresse exacte de votre entreprise ?",
#  'Où est située votre société ?',
#  'Où se situe votre société ?',
#  'Dans quelle zone se trouve votre entreprise ?',
#  "Pouvez-vous indiquer l'adresse de votre entreprise ?",
#  'Où est établie votre entreprise ?',
#  'Où se situe le siège de votre entreprise ?',
#  'Où est le siège de votre entreprise ?',
#  'Où est la localisation de votre entreprise ?',
#  "Quel est l'emplacement exact de votre entreprise ?",
#  'Où se trouve votre établissement ?',
#  'Où est situé votre établissement ?',
#  'Où votre entreprise est-elle localisée ?',
#  'Dans quelle localité se trouve votre entreprise ?',
#  'Où est basée votre entreprise ?',
#  "Quelle est l'adresse de votre société ?",
#  'Où se trouve exactement votre entreprise ?',
#  'Où est le bureau principal de votre entreprise ?',
#  'Dans quel pays se situe votre entreprise ?',
#  'Quel est le site de votre entreprise ?',
#  'Où est basé votre siège social ?',
#  'Où est le bureau central de votre entreprise ?',
#  'Où est situé votre siège social ?',
#  'Où votre société est-elle implantée ?',
#  'Quel est le lieu exact de votre entreprise ?',
#  'Où se trouve le siège de votre société ?',
#  'Où se situe le siège de votre société ?',
#  'Quelle est la région de votre entreprise ?',
#  'Quelle est la ville de votre entreprise ?',
#  'Où puis-je trouver votre entreprise ?',
#  'Où est votre siège social ?',
#  'Où est votre société ?',
#  'Où est localisé votre siège social ?',
#  'Où est la société située ?',
#  'Où se trouve le siège social de votre entreprise ?',
#  "Quel est l'adresse de votre siège social ?",
#  'Où se situe votre siège social ?',
#  'Quel est le lieu exact de votre société ?',
#  'Où votre siège social est-il situé ?',
#  "Où se trouve l'adresse de votre entreprise ?",
#  'Où se trouve la société ?',
#  'Dans quelle ville est située votre entreprise ?',
#  'Quel est le lieu de votre siège social ?',
#  'Où est la localisation exacte de votre entreprise ?',
#  "Quel est l'endroit où se trouve votre entreprise ?",
#  'Où puis-je localiser votre entreprise ?',
#  "Quelle est l'adresse où se trouve votre entreprise ?",
#  'Où se trouve exactement votre société ?',
#  'Quelle est la position géographique de votre entreprise ?',
#  'Où est située la société ?',
#  'Où est le lieu exact de votre siège social ?',
#  'Dans quel pays est située votre entreprise ?',
#  "Où est l'adresse exacte de votre siège social ?",
#  'Où est le bureau de votre entreprise ?',
#  'Quel est le lieu où est située votre entreprise ?',
#  'Où peut-on situer votre entreprise ?',
#  'Où est situé le siège social de votre société ?',
#  'Où est le lieu exact de votre société ?',
#  'Quels sont les principaux outils utilisés par la cellule backend ?',
#  'Quels outils principaux la cellule backend utilise-t-elle ?',
#  "Quels sont les outils de base utilisés par l'équipe backend ?",
#  'Quels outils sont essentiels pour la cellule backend ?',
#  'Quels outils utilisez-vous principalement dans la cellule backend ?',
#  'Quels sont les outils majeurs utilisés par le backend ?',
#  'Quels sont les outils couramment utilisés par la cellule backend ?',
#  'Quels sont les outils fondamentaux de la cellule backend ?',
#  'Quels outils la cellule backend utilise-t-elle généralement ?',
#  'Quels sont les outils principaux pour le backend ?',
#  'Quels outils sont privilégiés par la cellule backend ?',
#  'Quels outils utilisez-vous dans votre cellule backend ?',
#  'Quels outils la cellule backend utilise-t-elle principalement ?',
#  'Quels outils sont utilisés par la cellule backend ?',
#  'Quels outils sont communément utilisés par la cellule backend ?',
#  "Quels sont les principaux outils de l'équipe backend ?",
#  "Quels outils l'équipe backend utilise-t-elle ?",
#  'Quels sont les outils principaux employés par la cellule backend ?',
#  'Quels sont les outils clés de la cellule backend ?',
#  'Quels outils sont principalement utilisés dans la cellule backend ?',
#  'Quels outils sont utilisés couramment par la cellule backend ?',
#  'Quels outils la cellule backend préfère-t-elle ?',
#  'Quels sont les outils utilisés par votre équipe backend ?',
#  'Quels sont les outils essentiels pour le backend ?',
#  'Quels outils de backend utilisez-vous principalement ?',
#  'Quels sont les outils principaux pour votre backend ?',
#  'Quels sont les outils que la cellule backend utilise ?',
#  'Quels outils sont utilisés principalement par la cellule backend ?',
#  'Quels outils principaux votre cellule backend utilise-t-elle ?',
#  'Quels outils sont majoritairement utilisés par la cellule backend ?',
#  'Quels sont les outils utilisés par le backend ?',
#  'Quels outils utilisez-vous pour le backend ?',
#  'Quels sont les principaux outils pour le backend ?',
#  'Quels outils de backend utilisez-vous ?',
#  'Quels outils backend sont utilisés ?',
#  'Quels sont les outils utilisés principalement par votre cellule backend ?',
#  'Quels outils sont employés par la cellule backend ?',
#  'Quels sont les outils utilisés dans la cellule backend ?',
#  'Quels sont les outils backend essentiels ?',
#  'Quels sont les outils backend utilisés ?',
#  'Quels outils sont utilisés par votre cellule backend ?',
#  'Quels outils backend utilisez-vous ?',
#  'Quels outils sont cruciaux pour la cellule backend ?',
#  'Quels outils principaux utilisez-vous pour le backend ?',
#  'Quels outils backend sont couramment utilisés ?',
#  'Quels outils utilisez-vous principalement pour le backend ?',
#  'Quels sont les outils utilisés dans votre cellule backend ?',
#  'Quels sont les outils backend employés par la cellule ?',
#  'Quels outils utilisez-vous en backend ?',
#  'Quels sont les principaux outils pour votre cellule backend ?',
#  'Quels outils backend sont essentiels pour votre équipe ?',
#  'Quels sont les outils backend utilisés principalement ?',
#  'Quels outils backend la cellule utilise-t-elle ?',
#  'Quels outils backend sont employés couramment ?',
#  'Quels sont les outils backend utilisés principalement par votre équipe ?',
#  'Quels outils backend sont essentiels ?',
#  'Quels sont les outils principaux en backend ?',
#  'Quels outils backend utilisez-vous principalement ?',
#  'Quels sont les outils principaux pour la cellule backend ?',
#  'Quels outils backend sont courants ?',
#  'Quels sont les outils backend couramment utilisés ?',
#  'Quels sont les outils backend utilisés couramment ?',
#  'Quels outils backend utilisez-vous couramment ?',
#  'Quels outils backend sont majoritaires ?',
#  'Quels sont les outils backend de base ?',
#  'Quels outils backend sont employés principalement ?',
#  'Quels outils backend sont utilisés généralement ?',
#  'Quels sont les outils backend préférés ?',
#  'Quels outils backend sont utilisés majoritairement ?',
#  'Quels sont les outils backend cruciaux ?',
#  'Quels outils backend sont utilisés couramment par votre équipe ?',
#  'Quels outils backend utilisez-vous majoritairement ?',
#  'Quels sont les outils backend majeurs ?',
#  'Quels outils backend sont communément utilisés ?',
#  'Quels outils backend sont utilisés par votre équipe ?',
#  'Quels outils backend utilisez-vous dans votre équipe ?',
#  'Quels sont les outils backend courants ?',
#  'Quels sont les principaux outils utilisés par la cellule frontend ?',
#  'Quels outils principaux la cellule frontend utilise-t-elle ?',
#  "Quels sont les outils de base utilisés par l'équipe frontend ?",
#  'Quels outils sont essentiels pour la cellule frontend ?',
#  'Quels outils utilisez-vous principalement dans la cellule frontend ?',
#  'Quels sont les outils majeurs utilisés par le frontend ?',
#  'Quels sont les outils couramment utilisés par la cellule frontend ?',
#  'Quels sont les outils fondamentaux de la cellule frontend ?',
#  'Quels outils la cellule frontend utilise-t-elle généralement ?',
#  'Quels sont les outils principaux pour le frontend ?',
#  'Quels outils sont privilégiés par la cellule frontend ?',
#  'Quels outils utilisez-vous dans votre cellule frontend ?',
#  'Quels outils la cellule frontend utilise-t-elle principalement ?',
#  'Quels outils sont utilisés par la cellule frontend ?',
#  'Quels outils sont communément utilisés par la cellule frontend ?',
#  "Quels sont les principaux outils de l'équipe frontend ?",
#  "Quels outils l'équipe frontend utilise-t-elle ?",
#  'Quels sont les outils principaux employés par la cellule frontend ?',
#  'Quels sont les outils clés de la cellule frontend ?',
#  'Quels outils sont principalement utilisés dans la cellule frontend ?',
#  'Quels outils sont utilisés couramment par la cellule frontend ?',
#  'Quels outils la cellule frontend préfère-t-elle ?',
#  'Quels sont les outils utilisés par votre équipe frontend ?',
#  'Quels sont les outils essentiels pour le frontend ?',
#  'Quels outils de frontend utilisez-vous principalement ?',
#  'Quels sont les outils principaux pour votre frontend ?',
#  'Quels sont les outils que la cellule frontend utilise ?',
#  'Quels outils sont utilisés principalement par la cellule frontend ?',
#  'Quels outils principaux votre cellule frontend utilise-t-elle ?',
#  'Quels outils sont majoritairement utilisés par la cellule frontend ?',
#  'Quels sont les outils utilisés par le frontend ?',
#  'Quels outils utilisez-vous pour le frontend ?',
#  'Quels sont les principaux outils pour le frontend ?',
#  'Quels outils de frontend utilisez-vous ?',
#  'Quels outils frontend sont utilisés ?',
#  'Quels sont les outils utilisés principalement par votre cellule frontend ?',
#  'Quels outils sont employés par la cellule frontend ?',
#  'Quels sont les outils utilisés dans la cellule frontend ?',
#  'Quels sont les outils frontend essentiels ?',
#  'Quels sont les outils frontend utilisés ?',
#  'Quels outils sont utilisés par votre cellule frontend ?',
#  'Quels outils frontend utilisez-vous ?',
#  'Quels outils sont cruciaux pour la cellule frontend ?',
#  'Quels outils principaux utilisez-vous pour le frontend ?',
#  'Quels outils frontend sont couramment utilisés ?',
#  'Quels outils utilisez-vous principalement pour le frontend ?',
#  'Quels sont les outils utilisés dans votre cellule frontend ?',
#  'Quels sont les outils frontend employés par la cellule ?',
#  'Quels outils utilisez-vous en frontend ?',
#  'Quels sont les principaux outils pour votre cellule frontend ?',
#  'Quels outils frontend sont essentiels pour votre équipe ?',
#  'Quels sont les outils frontend utilisés principalement ?',
#  'Quels outils frontend la cellule utilise-t-elle ?',
#  'Quels outils frontend sont employés couramment ?',
#  'Quels sont les outils frontend utilisés principalement par votre équipe ?',
#  'Quels outils frontend sont essentiels ?',
#  'Quels sont les outils principaux en frontend ?',
#  'Quels outils frontend utilisez-vous principalement ?',
#  'Quels sont les outils principaux pour la cellule frontend ?',
#  'Quels outils frontend sont courants ?',
#  'Quels sont les outils frontend couramment utilisés ?',
#  'Quels sont les outils frontend utilisés couramment ?',
#  'Quels outils frontend utilisez-vous couramment ?',
#  'Quels outils frontend sont majoritaires ?',
#  'Quels sont les outils frontend de base ?',
#  'Quels outils frontend sont employés principalement ?',
#  'Quels outils frontend sont utilisés généralement ?',
#  'Quels sont les outils frontend préférés ?',
#  'Quels outils frontend sont utilisés majoritairement ?',
#  'Quels sont les outils frontend cruciaux ?',
#  'Quels outils frontend sont utilisés couramment par votre équipe ?',
#  'Quels outils frontend utilisez-vous majoritairement ?',
#  'Quels sont les outils frontend majeurs ?',
#  'Quels outils frontend sont communément utilisés ?',
#  'Quels outils frontend sont utilisés par votre équipe ?',
#  'Quels outils frontend utilisez-vous dans votre équipe ?',
#  'Quels sont les outils frontend courants ?',
#  "Quels sont vos outils de communication au sein de l'entreprise ?",
#  'Quels outils utilisez-vous pour la communication interne dans votre entreprise ?',
#  'Quels sont les principaux outils de communication utilisés dans votre entreprise ?',
#  "Quels sont vos outils de communication principaux au sein de l'entreprise ?",
#  'Quels outils utilisez-vous pour la communication au sein de votre entreprise ?',
#  'Quels sont les outils de communication internes que vous utilisez ?',
#  'Quels sont les outils de communication couramment utilisés dans votre entreprise ?',
#  'Quels outils utilisez-vous pour la communication interne ?',
#  'Quels sont les outils de communication préférés dans votre entreprise ?',
#  'Quels sont vos principaux outils de communication internes ?',
#  'Quels sont les outils de communication que vous utilisez le plus dans votre entreprise ?',
#  'Quels outils utilisez-vous principalement pour la communication interne ?',
#  'Quels sont vos outils de communication internes préférés ?',
#  'Quels sont vos principaux outils pour la communication interne ?',
#  'Quels sont les outils de communication utilisés quotidiennement dans votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus utilisés ?',
#  "Quels outils utilisez-vous le plus souvent pour la communication au sein de l'entreprise ?",
#  'Quels sont les outils de communication les plus importants dans votre entreprise ?',
#  'Quels sont vos outils de communication les plus efficaces ?',
#  'Quels sont les outils de communication que vous recommandez dans votre entreprise ?',
#  'Quels sont vos outils de communication essentiels au quotidien ?',
#  'Quels sont les outils de communication internes essentiels dans votre entreprise ?',
#  'Quels outils de communication utilisez-vous régulièrement ?',
#  "Quels sont vos outils de communication indispensables dans l'entreprise ?",
#  'Quels sont les outils de communication clés que vous utilisez ?',
#  'Quels sont les outils de communication les plus utilisés par votre équipe ?',
#  'Quels sont vos outils de communication internes recommandés ?',
#  'Quels outils de communication sont les plus pratiques pour votre équipe ?',
#  'Quels sont vos outils de communication internes favoris ?',
#  'Quels sont les outils de communication les plus efficaces pour votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus efficaces ?',
#  'Quels outils utilisez-vous habituellement pour la communication interne ?',
#  'Quels sont vos outils de communication internes courants ?',
#  'Quels sont vos outils de communication internes recommandés ?',
#  "Quels sont les outils de communication les plus utilisés au sein de l'entreprise ?",
#  'Quels sont vos outils de communication principaux recommandés ?',
#  'Quels outils de communication utilisez-vous fréquemment ?',
#  'Quels sont vos outils de communication internes favorisés ?',
#  'Quels sont les outils de communication que vous trouvez les plus utiles dans votre entreprise ?',
#  "Quels sont vos outils de communication les plus populaires au sein de l'entreprise ?",
#  'Quels sont les outils de communication internes que vous appréciez le plus ?',
#  "Quels sont vos outils de communication préférés dans l'entreprise ?",
#  'Quels outils de communication recommandez-vous pour une entreprise ?',
#  'Quels sont vos outils de communication internes les plus recommandés ?',
#  'Quels sont les outils de communication les plus recommandés dans votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus pratiques ?',
#  'Quels sont les outils de communication que vous trouvez les plus efficaces dans votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus utilisés quotidiennement ?',
#  'Quels outils de communication trouvez-vous les plus efficaces pour votre équipe ?',
#  'Quels sont vos outils de communication internes que vous préférez ?',
#  'Quels sont les outils de communication que vous recommandez le plus dans votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus populaires ?',
#  'Quels outils de communication sont les plus populaires dans votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus efficaces pour votre équipe ?',
#  'Quels sont les outils de communication internes que vous utilisez avec succès ?',
#  'Quels sont vos outils de communication internes les plus efficaces recommandés ?',
#  'Quels outils de communication sont recommandés pour une communication interne efficace ?',
#  'Quels outils de communication internes recommandez-vous ?',
#  'Quels sont vos outils de communication internes préférés et pourquoi ?',
#  'Quels sont les outils de communication internes que vous trouvez les plus efficaces ?',
#  'Quels outils de communication internes trouvez-vous les plus pratiques ?',
#  'Quels sont les outils de communication internes les plus utilisés pour votre équipe ?',
#  'Quels sont vos outils de communication internes favoris et pourquoi ?',
#  'Quels sont les outils de communication internes que vous trouvez les plus efficaces pour votre entreprise ?',
#  'Quels sont vos outils de communication internes les plus efficaces pour votre entreprise ?',
#  'Quels outils de communication recommanderiez-vous pour une équipe performante ?',
#  'Quels sont vos outils de communication internes recommandés pour une collaboration efficace ?',
#  'Quels sont vos outils de communication internes les plus pratiques pour votre équipe ?',
#  'Quels sont vos outils de communication internes recommandés pour une communication fluide ?',
#  'Quels sont vos outils de communication internes les plus efficaces recommandés pour votre équipe ?',
#  'Quels sont les outils de communication internes que vous recommandez pour une efficacité maximale ?',
#  'Quels sont vos outils de communication internes recommandés pour une meilleure collaboration ?',
#  'Quels sont les outils de communication internes que vous trouvez les plus utiles et pourquoi ?',
#  "Quels sont vos outils de communication internes recommandés pour une meilleure communication d'équipe ?",
#  'Quels outils de communication internes recommandez-vous pour une meilleure organisation ?',
#  'Quels sont vos outils de communication internes recommandés pour une coordination efficace ?',
#  'Quels sont vos outils de communication internes les plus utilisés et recommandés pour votre équipe ?',
#  'Quand est-ce que vous êtes ouverts ?',
#  "Quels sont vos horaires d'ouverture ?",
#  'À quels moments êtes-vous ouverts ?',
#  'Quand puis-je vous rendre visite ?',
#  'À quelles heures êtes-vous disponibles ?',
#  'Quand puis-je vous rencontrer ?',
#  "Quelles sont vos heures d'ouverture habituelles ?",
#  'À quels moments puis-je venir vous voir ?',
#  'Quand puis-je venir vous rendre visite ?',
#  'À quelles heures puis-je vous joindre ?',
#  'Quand est-ce que je peux venir vous voir ?',
#  'Quand puis-je passer vous voir ?',
#  'Quand est-ce que vous êtes disponibles ?',
#  'À quel moment êtes-vous ouverts ?',
#  'Quand puis-je vous visiter ?',
#  'Quand est-ce que vous êtes joignables ?',
#  'Quand êtes-vous ouverts au public ?',
#  'À quelles heures puis-je vous rencontrer ?',
#  'Quand puis-je venir vous rendre une visite ?',
#  'Quand êtes-vous accessibles ?',
#  'Quand est-ce que je peux vous contacter ?',
#  'Quand puis-je venir vous voir en personne ?',
#  'Quelles sont vos heures de service ?',
#  'À quel moment puis-je vous trouver ouverts ?',
#  'Quand puis-je vous rendre une visite ?',
#  'Quand êtes-vous en activité ?',
#  'Quand est-ce que vous acceptez les visiteurs ?',
#  'Quand puis-je venir vous rencontrer ?',
#  'Quand est-ce que vous recevez du public ?',
#  'Quand puis-je vous rendre visite ?',
#  'Quand êtes-vous disponibles pour une visite ?',
#  'À quel moment puis-je venir vous voir ?',
#  'Quand puis-je venir vous voir en personne ?',
#  'Quand puis-je passer vous voir ?',
#  'À quelles heures puis-je vous trouver ouverts ?',
#  'Quand est-ce que vous êtes disponibles pour des visites ?',
#  'Quand puis-je venir pour une consultation ?',
#  'Quand êtes-vous ouverts pour des rendez-vous ?',
#  'Quand puis-je vous rencontrer en personne ?',
#  'Quand est-ce que vous êtes accessibles ?',
#  'Quand puis-je venir vous voir pour des renseignements ?',
#  'Quand pouvez-vous me recevoir ?',
#  'À quel moment puis-je vous visiter ?',
#  'Quand puis-je vous rencontrer pour une discussion ?',
#  'Quand est-ce que je peux vous rencontrer pour une réunion ?',
#  'À quel moment puis-je vous rendre visite ?',
#  'Quand puis-je venir vous voir pour un entretien ?',
#  'Quand puis-je vous rencontrer pour une conversation ?',
#  'Quand est-ce que vous êtes ouverts aux visites ?',
#  'Quand puis-je vous voir pour une entrevue ?',
#  'Quand êtes-vous disponibles pour une rencontre ?',
#  'À quel moment puis-je vous joindre pour un rendez-vous ?',
#  'Quand puis-je vous voir pour une réunion ?',
#  'Quand pouvez-vous me recevoir pour une discussion ?',
#  'Quand puis-je venir pour une visite guidée ?',
#  'À quel moment puis-je vous contacter pour un rendez-vous ?',
#  'Quand est-ce que vous êtes ouverts pour une consultation ?',
#  'Quand puis-je vous voir pour une visite de votre établissement ?',
#  'Quand êtes-vous disponibles pour une entrevue ?',
#  'Quand puis-je vous rencontrer pour une visite guidée ?',
#  'À quel moment puis-je venir vous voir pour un entretien ?',
#  'Quand puis-je vous rencontrer pour une présentation ?',
#  'Quand est-ce que vous êtes accessibles pour une discussion ?',
#  'Quand puis-je vous visiter pour une découverte de vos services ?',
#  'Quand êtes-vous disponibles pour un rendez-vous ?',
#  'À quel moment puis-je vous rencontrer pour une réunion ?',
#  'Quand puis-je vous voir pour une présentation de vos produits ?',
#  'Quand pouvez-vous me recevoir pour une entrevue ?',
#  'Quand est-ce que je peux vous rencontrer pour des informations supplémentaires ?',
#  'Quand puis-je venir vous voir pour une visite de vos locaux ?',
#  'À quel moment puis-je vous joindre pour une réunion ?',
#  'Quand puis-je vous rencontrer pour une visite de vos installations ?',
#  'Quand est-ce que vous êtes disponibles pour une présentation de votre entreprise ?',
#  'Quand puis-je vous visiter pour découvrir vos services ?',
#  'Quand êtes-vous ouverts pour une consultation personnalisée ?',
#  'À quel moment puis-je vous rencontrer pour une démonstration de vos produits ?',
#  "C'est quoi Nokash?",
#  "Qu'est-ce que Nokash?",
#  "Pouvez-vous me dire ce qu'est Nokash?",
#  "Pourriez-vous m'expliquer ce que signifie Nokash?",
#  "Qu'est-ce que représente Nokash?",
#  "Je ne connais pas Nokash, pouvez-vous m'en dire plus?",
#  'Pourriez-vous définir Nokash pour moi?',
#  'Quel est le sens de Nokash?',
#  "Qu'est-ce que Nokash implique?",
#  'Quelle est la signification de Nokash?',
#  "C'est quoi Nokash exactement?",
#  'Pouvez-vous expliquer Nokash en détail?',
#  "Qu'est-ce que Nokash signifie pour vous?",
#  'Pourriez-vous me donner une explication claire de Nokash?',
#  "C'est quoi le concept de Nokash?",
#  "Qu'est-ce que Nokash englobe?",
#  'Quelle est la définition de Nokash?',
#  "C'est quoi Nokash en termes simples?",
#  'Pourriez-vous me clarifier Nokash?',
#  'Quelle est la nature de Nokash?',
#  'Je souhaite comprendre ce que Nokash représente.',
#  "Qu'est-ce que Nokash apporte?",
#  "Qu'est-ce qui caractérise Nokash?",
#  'Pourriez-vous me dire à propos de Nokash?',
#  "C'est quoi Nokash pour vous?",
#  'Quelle est la définition de Nokash pour votre entreprise?',
#  "Qu'est-ce que Nokash fait?",
#  'Comment Nokash fonctionne-t-il?',
#  'Quel est le but de Nokash?',
#  'Pourquoi Nokash est-il important?',
#  'Pourquoi devrais-je connaître Nokash?',
#  "C'est quoi Nokash pour l'entreprise?",
#  'Quelle est la fonction de Nokash?',
#  'Pouvez-vous me raconter Nokash?',
#  "Qu'est-ce que Nokash peut faire?",
#  'Pourquoi parlez-vous de Nokash?',
#  "Quelle est l'importance de Nokash?",
#  'Quelles sont les implications de Nokash?',
#  'Pouvez-vous me fournir des informations sur Nokash?',
#  'À quoi sert Nokash?',
#  'Quels sont les détails de Nokash?',
#  "Qu'est-ce que Nokash représente pour vous?",
#  'Pourriez-vous me renseigner sur Nokash?',
#  "Qu'est-ce que Nokash engendre?",
#  'Quelles sont les caractéristiques de Nokash?',
#  "C'est quoi Nokash en un mot?",
#  'Pourquoi est-ce que vous mentionnez Nokash?',
#  "C'est quoi l'objectif de Nokash?",
#  "Qu'est-ce que Nokash inclut?",
#  "Qu'est-ce qui rend Nokash spécial?",
#  'Pouvez-vous me donner des détails sur Nokash?',
#  'Quelle est la signification de Nokash pour vous?',
#  'Comment définiriez-vous Nokash?',
#  "Qu'est-ce que Nokash enseigne?",
#  "C'est quoi Nokash pour les clients?",
#  'Pouvez-vous clarifier Nokash?',
#  "Qu'est-ce que Nokash vise à accomplir?",
#  'Quelle est la mission de Nokash?',
#  'Pourquoi est-ce que Nokash existe?',
#  "C'est quoi Nokash dans votre contexte?",
#  "Quelle est l'essence de Nokash?",
#  "Qu'est-ce que Nokash offre?",
#  'Pouvez-vous décrire Nokash?',
#  "Qu'est-ce que Nokash propose?",
#  "C'est quoi Nokash pour votre entreprise?",
#  "Qu'est-ce que Nokash apporte à vos utilisateurs?",
#  'Quelles sont les fonctionnalités de Nokash?',
#  "Pourquoi devrais-je m'intéresser à Nokash?",
#  "Pouvez-vous m'éclairer sur Nokash?",
#  "Qu'est-ce que Nokash signifie pour l'industrie?",
#  'Pourquoi Nokash est-il pertinent?',
#  "C'est quoi Nokash pour votre équipe?",
#  "Qu'est-ce que Nokash implique pour vous?",
#  "Qu'est-ce que Nokash représente pour vos clients?",
#  "C'est quoi Nokash en pratique?",
#  'Quelle est la portée de Nokash?',
#  "Qu'est-ce que Nokash vous apprend?",
#  "C'est quoi Nokash en quelques mots?",
#  'Quels sont les bénéfices de Nokash?',
#  "Pouvez-vous m'expliquer Nokash en quelques phrases?",
#  'Quelles sont les applications de Nokash?',
#  "Qu'est-ce que Nokash symbolise?",
#  "C'est quoi Nokash pour les utilisateurs?",
#  "Qu'est-ce que Nokash réalise?",
#  "Qu'est-ce que Nokash propose comme solutions?",
#  "C'est quoi Nokash en détail?",
#  "Quelle est l'importance de Nokash dans votre secteur?",
#  'Quelles sont les valeurs de Nokash?',
#  'Quelles sont les qualités de Nokash?',
#  "C'est quoi Taxcollect?",
#  ...]

# %% [markdown]
# ## PIPELINE SCIKIT-LEARN

# %% [markdown]
# Un pipeline est créé avec CountVectorizer pour convertir les textes en vecteurs de mots, TfidfTransformer pour appliquer la pondération TF-IDF, et SGDClassifier comme classificateur linéaire avec descente de gradient stochastique.

# %%
# Division des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(patterns, y, test_size=0.2, random_state=42)

# Création du pipeline avec CountVectorizer, TfidfTransformer et SGDClassifier
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=1e-3, random_state=42,
                          max_iter=1000, tol=1e-3)),
])

# %% [markdown]
# ## ENTRAINEMENT ET EVALUATION DU MODELE

# %% [markdown]
# Le modèle est entraîné avec pipeline.fit(X, y) sur les données d'entraînement.

# %%
# Entraînement du modèle
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', SGDClassifier(alpha=0.001, random_state=42))])

# %%
# Évaluation du modèle
y_pred_train = pipeline.predict(X_train)
accuracy_train = accuracy_score(y_train, y_pred_train)
print(f'Précision avec données entraînement: {accuracy_train}')
# Out:
# Précision avec données entraînement: 0.9983416252072969

# %%
y_pred_test = pipeline.predict(X_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
print(f'Précision avec données test: {accuracy_test}')
# Out:
# Précision avec données test: 0.9823399558498896

# %%
# Fonction pour prédire la classe
def predict_class(text):
    predicted = pipeline.predict([text])
    return label_encoder.inverse_transform(predicted)[0]

# %%
# Fonction pour obtenir la réponse
def get_response(tag):
    return random.choice(responses[tag])

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        16
#            3       1.00      1.00      1.00        14
#            4       1.00      1.00      1.00        15
#            5       1.00      1.00      1.00        24
#            6       1.00      1.00      1.00        10
#            7       1.00      0.79      0.88        14
#            8       0.79      1.00      0.88        11
#            9       0.91      1.00      0.95        10
#           10       1.00      0.94      0.97        18
#           11       1.00      1.00      1.00        12
#           12       1.00      0.93      0.97        15
#           13       0.00      0.00      0.00         2
#           14       1.00      1.00      1.00        17
#           15       1.00      1.00      1.00         8
#           16       1.00      0.94      0.97        18
#           17       1.00      1.00      1.00         6
#           18       1.00      1.00      1.00        18
#           19       0.90      1.00      0.95         9
#           20       1.00      1.00      1.00        12
#           21       1.00      1.00      1.00        16
#           22       1.00      1.00      1.00        21
#           23       1.00      1.00      1.00        18
#           24       1.00      1.00      1.00        15
#           25       1.00      1.00      1.00        11
#           26       1.00      1.00      1.00        20
#           27       1.00      1.00      1.00        16
#           28       0.89      1.00      0.94        17
#           29       1.00      1.00      1.00        11
#           30       1.00      1.00      1.00        19
#           31       0.94      1.00      0.97        16
#           32       1.00      1.00      1.00        14
#
#     accuracy                           0.98       453
#    macro avg       0.95      0.96      0.95       453
# weighted avg       0.98      0.98      0.98       453
# /home/ariel/PycharmProjects/enronmails/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ariel/PycharmProjects/enronmails/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ariel/PycharmProjects/enronmails/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## AFFICHAGE GRAPHIQUE

# %%
import tkinter
from tkinter import *
from tkinter import scrolledtext
from tkinter import messagebox
import random

# %%
# Interface Utilisateur avec Tkinter
def send():
    question = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if question != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "Moi: " + question + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12))
    
        tag = predict_class(question)
        response = get_response(tag)
        
        ChatBox.insert(END, "K-ARL: " + response + '\n\n')
        
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)

# %%
root = Tk()
root.title("K-ARL CHATBOT")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)

# Création de la zone de chat
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial")
ChatBox.config(state=DISABLED)

# Ajout de la barre de défilement
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set

# Création du bouton "Envoyer"
SendButton = Button(root, font=("Verdana", 12, 'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b", fg='#000000',
                    command=send)

# Création de la zone de saisie
EntryBox = Text(root, bd=0, bg="white", width="29", height="5", font="Arial")

# Placement des composants sur l'écran
scrollbar.place(x=376, y=6, height=386)
ChatBox.place(x=6, y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

root.mainloop()
